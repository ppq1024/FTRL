# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim import Adam, SGD, AdamW

import torchvision.transforms as T
from torchvision.datasets import FashionMNIST

import time

from tqdm import tqdm

from ftrl import FTRL, FTRLAdam


DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

t_train = T.Compose([
    T.RandomHorizontalFlip(),
    T.ToTensor()
])
t_test = T.Compose([
    T.ToTensor()
])
bs = 32
train_set = FashionMNIST(root='./data', train=True, download=True, transform=t_train)
test_set = FashionMNIST(root='./data', train=False, download=True, transform=t_test)
train_loader = DataLoader(train_set, batch_size=bs, shuffle=True, num_workers=12, pin_memory=True, persistent_workers=True)
test_loader = DataLoader(test_set, batch_size=bs, shuffle=False, num_workers=12, pin_memory=True, persistent_workers=True)

# preload data
for _ in train_loader: break
for _ in test_loader: break

def train_and_test(model, optimizer, epochs=5):
    loss_function = nn.CrossEntropyLoss()
    for epoch in range(epochs):
        start_time = time.time()
        train_num = 0
        train_right = 0
        train_loss = 0
        model.train()
        for x, y in tqdm(train_loader, desc=f"epoch {epoch} train", total=len(train_loader), unit_scale=bs):
            num = len(x)
            x, y = x.to(DEVICE), y.to(DEVICE)
            y_hat = model(x)
            loss = loss_function(y_hat, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_num += num
            train_right += (y_hat.argmax(dim=1) == y).sum().item()
            train_loss += loss.item()
        train_acc = train_right / train_num
        train_loss /= train_num

        with torch.no_grad():
            model.eval()
            test_num = 0
            test_right = 0
            test_loss = 0
            for x, y in test_loader:
                num = len(x)
                x, y = x.cuda(), y.cuda()
                y_hat = model(x)
                loss = loss_function(y_hat, y)
                test_num += num
                test_right += (y_hat.argmax(dim=1) == y).sum().item()
                test_loss += loss.item()
            test_acc = test_right / test_num
            test_loss /= test_num
        print(f"epoch: {epoch}, train_acc: {train_acc * 100:.2f}%, train_loss: {train_loss:.2e}, test_acc: {test_acc * 100:.2f}%, test_loss: {test_loss:.2e}, time used: {time.time() - start_time:.3f}s")


model_cnn = lambda : nn.Sequential(
    nn.Conv2d(1, 16, 5, padding="same"),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Conv2d(16, 16, 5, padding="same"),
    nn.ReLU(),
    nn.MaxPool2d(2),
    nn.Flatten(),
    nn.Linear(16*7*7, 1024),
    nn.ReLU(),
    nn.Linear(1024, 10)
).to(DEVICE)

# %%
print("SGD:")
model = model_cnn()
optimizer = SGD(model.parameters(), lr=1.0e-3, weight_decay=1.0e-5)
train_and_test(model, optimizer)
print("AdamW:")
model = model_cnn()
optimizer = AdamW(model.parameters(), lr=1.0e-3, weight_decay=1.0e-5)
train_and_test(model, optimizer)
print("FTRL:")
model = model_cnn()
optimizer = FTRL(model.parameters(), lr=1.0e-3, weight_decay=1.0e-5)
train_and_test(model, optimizer)
print("FTRLAdam:")
model = model_cnn()
optimizer = FTRLAdam(model.parameters(), lr=1.0e-3, weight_decay=1.0e-5)
train_and_test(model, optimizer)
# Out:
# SGD:
# epoch 0 train: 100%|██████████| 60000/60000 [00:05<00:00, 10652.85it/s]
# epoch: 0, train_acc: 35.68%, train_loss: 6.44e-02, test_acc: 61.49%, test_loss: 4.12e-02, time used: 6.009s
# epoch 1 train: 100%|██████████| 60000/60000 [00:04<00:00, 13927.93it/s]
# epoch: 1, train_acc: 65.79%, train_loss: 3.06e-02, test_acc: 68.65%, test_loss: 2.69e-02, time used: 4.649s
# epoch 2 train: 100%|██████████| 60000/60000 [00:04<00:00, 13249.91it/s]
# epoch: 2, train_acc: 70.97%, train_loss: 2.49e-02, test_acc: 68.21%, test_loss: 2.54e-02, time used: 4.900s
# epoch 3 train: 100%|██████████| 60000/60000 [00:04<00:00, 14256.09it/s]
# epoch: 3, train_acc: 73.58%, train_loss: 2.28e-02, test_acc: 73.90%, test_loss: 2.27e-02, time used: 4.542s
# epoch 4 train: 100%|██████████| 60000/60000 [00:04<00:00, 14623.53it/s]
# epoch: 4, train_acc: 75.49%, train_loss: 2.13e-02, test_acc: 74.83%, test_loss: 2.18e-02, time used: 4.435s
# AdamW:
# epoch 0 train: 100%|██████████| 60000/60000 [00:04<00:00, 13935.95it/s]
# epoch: 0, train_acc: 83.66%, train_loss: 1.40e-02, test_acc: 86.94%, test_loss: 1.12e-02, time used: 4.656s
# epoch 1 train: 100%|██████████| 60000/60000 [00:04<00:00, 13898.83it/s]
# epoch: 1, train_acc: 89.27%, train_loss: 9.14e-03, test_acc: 88.65%, test_loss: 9.83e-03, time used: 4.662s
# epoch 2 train: 100%|██████████| 60000/60000 [00:04<00:00, 13435.04it/s]
# epoch: 2, train_acc: 90.63%, train_loss: 7.89e-03, test_acc: 89.78%, test_loss: 8.47e-03, time used: 4.795s
# epoch 3 train: 100%|██████████| 60000/60000 [00:04<00:00, 13213.88it/s]
# epoch: 3, train_acc: 91.46%, train_loss: 7.11e-03, test_acc: 90.50%, test_loss: 8.21e-03, time used: 4.878s
# epoch 4 train: 100%|██████████| 60000/60000 [00:04<00:00, 13513.27it/s]
# epoch: 4, train_acc: 92.36%, train_loss: 6.46e-03, test_acc: 90.41%, test_loss: 8.29e-03, time used: 4.777s
# FTRL:
# epoch 0 train: 100%|██████████| 60000/60000 [00:05<00:00, 11153.64it/s]
# epoch: 0, train_acc: 21.25%, train_loss: 7.15e-02, test_acc: 44.86%, test_loss: 7.05e-02, time used: 5.751s
# epoch 1 train: 100%|██████████| 60000/60000 [00:05<00:00, 10781.07it/s]
# epoch: 1, train_acc: 53.49%, train_loss: 6.23e-02, test_acc: 60.73%, test_loss: 4.48e-02, time used: 5.891s
# epoch 2 train: 100%|██████████| 60000/60000 [00:05<00:00, 10980.01it/s]
# epoch: 2, train_acc: 65.72%, train_loss: 3.45e-02, test_acc: 68.84%, test_loss: 2.89e-02, time used: 5.807s
# epoch 3 train: 100%|██████████| 60000/60000 [00:05<00:00, 10858.43it/s]
# epoch: 3, train_acc: 70.74%, train_loss: 2.65e-02, test_acc: 71.51%, test_loss: 2.53e-02, time used: 5.851s
# epoch 4 train: 100%|██████████| 60000/60000 [00:05<00:00, 10889.81it/s]
# epoch: 4, train_acc: 72.56%, train_loss: 2.41e-02, test_acc: 72.85%, test_loss: 2.37e-02, time used: 5.830s
# FTRLAdam:
# epoch 0 train: 100%|██████████| 60000/60000 [00:06<00:00, 9078.07it/s]
# epoch: 0, train_acc: 83.24%, train_loss: 1.43e-02, test_acc: 87.43%, test_loss: 1.09e-02, time used: 6.950s
# epoch 1 train: 100%|██████████| 60000/60000 [00:06<00:00, 9753.38it/s]
# epoch: 1, train_acc: 89.08%, train_loss: 9.30e-03, test_acc: 89.20%, test_loss: 9.17e-03, time used: 6.477s
# epoch 2 train: 100%|██████████| 60000/60000 [00:06<00:00, 9641.62it/s]
# epoch: 2, train_acc: 90.56%, train_loss: 7.96e-03, test_acc: 90.05%, test_loss: 8.51e-03, time used: 6.563s
# epoch 3 train: 100%|██████████| 60000/60000 [00:05<00:00, 10022.73it/s]
# epoch: 3, train_acc: 91.39%, train_loss: 7.17e-03, test_acc: 90.86%, test_loss: 7.85e-03, time used: 6.300s
# epoch 4 train: 100%|██████████| 60000/60000 [00:06<00:00, 9469.82it/s]
# epoch: 4, train_acc: 92.17%, train_loss: 6.54e-03, test_acc: 90.52%, test_loss: 7.96e-03, time used: 6.665s

# %%
print("FTRL without foreach:")
model = model_cnn()
optimizer = FTRL(model.parameters(), lr=1.0e-3, weight_decay=1.0e-5, foreach=False)
train_and_test(model, optimizer)
print("FTRLAdam without foreach:")
model = model_cnn()
optimizer = FTRLAdam(model.parameters(), lr=1.0e-3, weight_decay=1.0e-5, foreach=False)
train_and_test(model, optimizer)
# Out:
# FTRL without foreach:
# epoch 0 train: 100%|██████████| 60000/60000 [00:08<00:00, 7285.78it/s]
# epoch: 0, train_acc: 39.36%, train_loss: 6.24e-02, test_acc: 57.57%, test_loss: 4.26e-02, time used: 8.622s
# epoch 1 train: 100%|██████████| 60000/60000 [00:08<00:00, 6956.50it/s]
# epoch: 1, train_acc: 64.41%, train_loss: 3.30e-02, test_acc: 66.92%, test_loss: 2.90e-02, time used: 8.963s
# epoch 2 train: 100%|██████████| 60000/60000 [00:07<00:00, 7952.83it/s]
# epoch: 2, train_acc: 69.11%, train_loss: 2.69e-02, test_acc: 69.94%, test_loss: 2.63e-02, time used: 7.874s
# epoch 3 train: 100%|██████████| 60000/60000 [00:07<00:00, 7648.30it/s]
# epoch: 3, train_acc: 71.28%, train_loss: 2.49e-02, test_acc: 71.80%, test_loss: 2.47e-02, time used: 8.193s
# epoch 4 train: 100%|██████████| 60000/60000 [00:07<00:00, 7619.16it/s]
# epoch: 4, train_acc: 73.07%, train_loss: 2.36e-02, test_acc: 72.28%, test_loss: 2.39e-02, time used: 8.200s
# FTRLAdam without foreach:
# epoch 0 train: 100%|██████████| 60000/60000 [00:08<00:00, 6993.22it/s]
# epoch: 0, train_acc: 83.30%, train_loss: 1.43e-02, test_acc: 86.33%, test_loss: 1.15e-02, time used: 8.920s
# epoch 1 train: 100%|██████████| 60000/60000 [00:08<00:00, 7026.70it/s]
# epoch: 1, train_acc: 88.99%, train_loss: 9.25e-03, test_acc: 89.32%, test_loss: 9.10e-03, time used: 8.924s
# epoch 2 train: 100%|██████████| 60000/60000 [00:08<00:00, 6923.28it/s]
# epoch: 2, train_acc: 90.58%, train_loss: 7.98e-03, test_acc: 90.17%, test_loss: 8.41e-03, time used: 9.056s
# epoch 3 train: 100%|██████████| 60000/60000 [00:09<00:00, 6184.85it/s]
# epoch: 3, train_acc: 91.38%, train_loss: 7.18e-03, test_acc: 90.22%, test_loss: 8.32e-03, time used: 10.063s
# epoch 4 train: 100%|██████████| 60000/60000 [00:09<00:00, 6128.38it/s]
# epoch: 4, train_acc: 92.13%, train_loss: 6.56e-03, test_acc: 90.91%, test_loss: 7.74e-03, time used: 10.184s
